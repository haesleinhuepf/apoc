# %%
import pyclesperanto_prototype as clep
clep.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pyclesperanto_prototype as clep
#       2 clep.__version__
#
# File ~\miniforge3\envs\bob-env\Lib\site-packages\pyclesperanto_prototype\__init__.py:1
# ----> 1 from ._tier0 import *
#       2 from ._tier1 import *
#       3 from ._tier2 import *
#
# File ~\miniforge3\envs\bob-env\Lib\site-packages\pyclesperanto_prototype\_tier0\__init__.py:36
#      34 from ._push import push
#      35 from ._push import push as asarray
# ---> 36 from ._plugin_function import plugin_function
#      37 from ._types import Image
#      38 from ._cl_info import cl_info
#
# File ~\miniforge3\envs\bob-env\Lib\site-packages\pyclesperanto_prototype\_tier0\_plugin_function.py:8
#       4 from toolz import curry
#       7 from ._create import create_like
# ----> 8 from ._types import Image, is_image
# ...

# %%
import pyclesperanto as cle
cle.__version__
